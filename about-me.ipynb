# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Lucila"
reason = "I want to learn data analytics to analyze my own research projects in the laboratory. "
fun_fact = "I work in biomedical research, specifically in cancer diagnosis (genomics). I work with huge amounts of data and always need someone to analyze it for me, which is why I want to learn more and do it all myself. "

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Lucila. I’m excited to learn because I want to learn data analytics to analyze my own research projects in the laboratory. . A fun fact about me is: I work in biomedical research, specifically in cancer diagnosis (genomics). I work with huge amounts of data and always need someone to analyze it for me, which is why I want to learn more and do it all myself. .
